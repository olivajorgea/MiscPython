# %% [markdown]
# # Programing *Data Science*

# %% [markdown]
# Step 1: Environment programing Installation and configuration
# --------------------------------------------

# %% [markdown]
# ## ¡Working!

# %%
hello!
